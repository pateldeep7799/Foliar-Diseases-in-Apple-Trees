# %%
# !pip install natsort

# %%
import numpy as np
import pandas as pd
import os
from re import search
import shutil
import natsort
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import tqdm

# %%
DIR = r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images'

# %%
train = pd.read_csv(r"C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\train.csv")
test = pd.read_csv(r"C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\test.csv")

# %%
image1 = Image.open(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\Test_0.jpg')
plt.imshow(image1)

# %% [markdown]
# # Preparing the Data

# %%
class_names = train.loc[:,'healthy':].columns
print(class_names)
# Out:
# Index(['healthy', 'multiple_diseases', 'rust', 'scab'], dtype='object')

# %%
number=0
train['label']=0
for i in class_names:
    train['label'] = train['label'] + train[i] * number
    number = number+1

# %%
def get_label_img(img):
    if search("Train",img):
        img = img.split('.')[0]
        label = train.loc[train['image_id']==img]['label']
        return label

# %%
def create_train_data():
    images = natsort.natsorted(os.listdir(DIR))
    for img in images:
        label = get_label_img(img)
        path = os.path.join(DIR,img)
        
        if search("Train",img):
            if(img.split("_")[1].split(".")[0]) and label.item() == 0:
                shutil.copy(path, r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\healthy')
                
            elif(img.split("_")[1].split(".")[0]) and label.item() == 1:
                shutil.copy(path, r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\multiple_disease')
                
            elif(img.split("_")[1].split(".")[0]) and label.item() == 2:
                shutil.copy(path, r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\rust')
                
            elif(img.split("_")[1].split(".")[0]) and label.item() == 3:
                shutil.copy(path, r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\scab')
                
        elif search("Test", img):
            shutil.copy(path,r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\test')

# %%
shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train')
shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\healthy')
shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\multiple_disease')
shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\rust')
shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\train\scab')

shutil.os.mkdir(r'C:\Users\HP\Desktop\plant-pathology-2020-fgvc7\images\test')

# %%
train_dir= create_train_data()
